# %% [markdown]
# ## 1.4.1 算术运算
#
# * add 加
# * subtract 减
# * multiple 乘
# * divide 除
#
# ## 1.4.2 数学运算
#
# * 三角函数：sin、cos、tan
# * 算术运算
#
# ## 1.4.3 统计运算
#
# * mean 均值
# * average 均值
# * var 方差
# * std 标准差
#
# ## 1.4.4 聚合运算
#
# * 性能区别：np聚合函数 vs py内置函数
# * sum 累加
# * prod 累乘
# * max 最大值
# * min 最小值
# * 统计运算
#
# ## 1.4.5 筛选与排序
#
# * where函数
# * sort函数

# %%
import numpy as np

# %%
# 1. 算术运算
a = np.random.random(10000)*10
b = np.random.random(10000)*10

# %%
a
# Out:
# array([3.11228507, 0.98885169, 7.92147135, ..., 4.77569434, 1.68780735,
#        8.86772547])

# %%
b
# Out:
# array([1.43869067, 4.74541133, 5.92487487, ..., 8.33911195, 7.46695737,
#        1.78011698])

# %%
# 既可以运算符，使用np算术函数
a + b
# Out:
# array([ 4.55097574,  5.73426302, 13.84634621, ..., 13.11480628,
#         9.15476472, 10.64784245])

# %%
np.add?

# %%
np.add(a,b)
# Out:
# array([ 4.55097574,  5.73426302, 13.84634621, ..., 13.11480628,
#         9.15476472, 10.64784245])

# %%
a - b
# Out:
# array([ 1.67359439, -3.75655964,  1.99659648, ..., -3.56341761,
#        -5.77915002,  7.0876085 ])

# %%
np.subtract(a,b)
# Out:
# array([ 1.67359439, -3.75655964,  1.99659648, ..., -3.56341761,
#        -5.77915002,  7.0876085 ])

# %%
a*b
# Out:
# array([ 4.4776155 ,  4.69250802, 46.93372649, ..., 39.8250497 ,
#        12.60278554, 15.78558865])

# %%
np.multiply(a,b)
# Out:
# array([ 4.4776155 ,  4.69250802, 46.93372649, ..., 39.8250497 ,
#        12.60278554, 15.78558865])

# %%
a/b
# Out:
# array([2.16327604, 0.20838061, 1.33698543, ..., 0.5726862 , 0.22603683,
#        4.98154087])

# %%
np.divide(a,b)
# Out:
# array([2.16327604, 0.20838061, 1.33698543, ..., 0.5726862 , 0.22603683,
#        4.98154087])

# %% [markdown]
# ### 2. 数学函数
#
# 1°=π/180 rad
#
# ![image.png](attachment:image.png)

# %%
ang = np.array([0,30,45,60,90,120,135,150,180])
rad = np.sin(ang*np.pi/180)

# %%
rad
# Out:
# array([0.00000000e+00, 5.00000000e-01, 7.07106781e-01, 8.66025404e-01,
#        1.00000000e+00, 8.66025404e-01, 7.07106781e-01, 5.00000000e-01,
#        1.22464680e-16])

# %%
# 3. 统计函数
d2 = np.array([1,2,3,4,5])
d2
# Out:
# array([1, 2, 3, 4, 5])

# %%
d2.mean()
# Out:
# 3.0

# %%
np.average(d2)
# Out:
# 3.0

# %%
np.average?

# %%
np.average(d2,weights=np.array([2,2,1,1,1]))
# Out:
# 2.5714285714285716

# %%
np.average(d2,weights=np.array([1,1,1,2,3]))
# Out:
# 3.625

# %%
# 中位数
np.median(d2)
# Out:
# 3.0

# %%
d3 = np.array([1,2,3,4,5,6])
np.median(d3)
# Out:
# 3.5

# %%
# 方差
np.var(d3)
# Out:
# 2.9166666666666665

# %%
# 标准差
np.std(d3)
# Out:
# 1.707825127659933

# %%
# 3.聚合运算
a
# Out:
# array([3.11228507, 0.98885169, 7.92147135, ..., 4.77569434, 1.68780735,
#        8.86772547])

# %%
# %time sum(a)
# %time np.sum(a)

# %%
np.prod(d2)

# %%
np.max(d2)

# %%
# 5. 筛选、排序
d3

# %%
np.where(d3>3)

# %%
np.where?

# %%
np.where(d3<3)

# %%
np.sort([5,4,2,7,2,1])
