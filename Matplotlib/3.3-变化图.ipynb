# %%
## 3.3 变化图：随着时间的趋势变化，折线图、堆叠面积图

# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd

# %%
# 3.3.1 简单示例
sample1 = np.random.random(100)

# %%
plt.plot(sample1)

# %%
plt.plot(sample1,color='red')
plt.fill_between(np.arange(100),y1=sample1,y2=0,alpha='0.5')
plt.xlim(0,100)
plt.ylim(0,1)
# Out:
# (0, 1)

# %%
# 3.3.2 股票数据示例：日期、价格

# %%
dates = pd.date_range('20180101','20210101',freq='M')

# %%
def get_price(size):
    return np.cumsum(np.random.randn(size))

size = len(dates)
price1 = get_price(size)
price2 = get_price(size)
price3 = get_price(size)

# %%
fig,ax = plt.subplots(1,1)

ax.plot(dates,price1)
ax.plot(dates,price2)
ax.plot(dates,price3)

fig.autofmt_xdate() # 自动调整x轴标签显示方式，以完整显示

# %%
# 整合成dataframe -> 再直接绘图
data = pd.DataFrame([price1,price2,price3]).T
data.index = dates
data
# Out:
#                     0         1         2
# 2018-01-31   0.477531 -0.586994 -1.013587
# 2018-02-28   1.982780 -2.900921  0.365248
# 2018-03-31   1.641603 -4.352982  1.253957
# 2018-04-30   1.178612 -4.539283  3.184484
# 2018-05-31   0.564140 -5.397697  3.131738
# 2018-06-30   1.463871 -3.922104  2.490300
# 2018-07-31   2.609817 -4.664869  3.686260
# 2018-08-31   3.950329 -5.277242  4.745597
# 2018-09-30   5.017767 -5.617024  6.240052
# 2018-10-31   4.533927 -4.434215  5.542330
# 2018-11-30   5.054948 -5.332132  5.647636
# 2018-12-31   4.948184 -4.565493  4.970160
# 2019-01-31   7.005908 -4.594144  5.457931
# 2019-02-28   6.973427 -4.221211  4.361577
# 2019-03-31   6.576052 -3.620310  4.800224
# 2019-04-30   6.360100 -2.357777  6.091329
# 2019-05-31   6.207718 -1.866924  6.018571
# 2019-06-30   6.113318 -0.575815  5.989102
# 2019-07-31   4.547487 -2.113529  5.345203
# 2019-08-31   4.658719 -3.378745  4.760425
# 2019-09-30   5.187221 -3.759131  4.598724
# 2019-10-31   5.888984 -3.838183  3.924662
# 2019-11-30   8.052446 -5.076792  2.713796
# 2019-12-31   7.217496 -3.515230  1.534884
# 2020-01-31   7.347439 -5.708704  1.406060
# 2020-02-29   9.099529 -2.604762  1.943142
# 2020-03-31  10.622071 -2.759255  1.420238
# 2020-04-30   9.597658 -0.254335  1.279158
# 2020-05-31   7.894679 -0.622332  1.708988
# 2020-06-30   7.789952  1.396726  0.758863
# 2020-07-31   7.757982  0.668974  0.892632
# 2020-08-31   5.357968  2.394955 -2.307049
# 2020-09-30   5.834958  3.772255 -3.265128
# 2020-10-31   6.257973  4.555215 -4.195653
# 2020-11-30   7.307084  2.301198 -4.126622
# 2020-12-31   6.654564  3.504691 -3.924370

# %%
data.plot()

# %%
plt.plot(data)
# Out:
# [<matplotlib.lines.Line2D at 0x1206bf350>,
#  <matplotlib.lines.Line2D at 0x12029e1d0>,
#  <matplotlib.lines.Line2D at 0x12029e390>]

# %%
# 创建未堆叠面积图
fig,ax = plt.subplots(1,1)

ax.plot(dates,price1)
ax.plot(dates,price2)
ax.plot(dates,price3)

fig.autofmt_xdate() # 自动调整x轴标签显示方式，以完整显示

# 填充颜色、面积
plt.fill_between(dates,y1=price1,alpha=0.5)
plt.fill_between(dates,y1=price2,alpha=0.5)
plt.fill_between(dates,y1=price3,alpha=0.5)

# %%
Ω
