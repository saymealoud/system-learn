# %% [markdown]
# ## 2.2.1 函数调用：pyplot、pylab
#
# * pyplot：创建画板、示例图
# * pylab：结合pyplot和numpy函数的调用，功能比较复杂，不建议使用
#
# ## 2.2.2 创建画板（操作对象）
#
# * plt.figure，设置图形大小，返回figure画板对象
# * plt.subplots，设置行数、列数，创建相应数量的axes对象
#
# ## 2.2.3 生成图表
#
# ## 2.2.4 配置图例
#
# * title，设置图表标题
# * axis/xlim/ylim：设置坐标轴范围
# * grid：添加图表网格线
# * legend：添加label图例参数并显示
# * xlabel/ylabel：设置x、y轴标题
# * xticks/yticks：定义坐标轴刻度显示
# * text/arrow/annotation：分别在图例指定位置添加文字、箭头和标记

# %%
pip install matplotlib
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
import matplotlib.pyplot as plt

# %%
# 创建figure、subplots
plt.subplots
# Out:
# <function matplotlib.pyplot.subplots(nrows: 'int' = 1, ncols: 'int' = 1, *, sharex: "bool | Literal['none', 'all', 'row', 'col']" = False, sharey: "bool | Literal['none', 'all', 'row', 'col']" = False, squeeze: 'bool' = True, width_ratios: 'Sequence[float] | None' = None, height_ratios: 'Sequence[float] | None' = None, subplot_kw: 'dict[str, Any] | None' = None, gridspec_kw: 'dict[str, Any] | None' = None, **fig_kw) -> 'tuple[Figure, Any]'>

# %%
plt.subplots(2, 2)
# Out:
# (<Figure size 640x480 with 4 Axes>,
#  array([[<Axes: >, <Axes: >],
#         [<Axes: >, <Axes: >]], dtype=object))

# %%
fig, axs = plt.subplots(2, 1)

# %%
# 生成数据
import numpy as np
data = np.random.randn(100)
data
# Out:
# array([-5.31137984e-01, -6.91824606e-01, -7.35559976e-01, -2.67751526e+00,
#        -8.75865332e-01, -4.20781774e-04,  2.35283728e-01,  5.39393369e-01,
#         4.48536959e-01,  6.16768893e-01,  3.83340572e-01, -7.93393395e-01,
#         1.89282870e+00, -1.40885831e+00,  1.52595422e-02, -1.03801009e+00,
#        -1.22783739e+00,  1.27373886e+00, -2.30955869e+00,  1.43083454e+00,
#        -1.17168921e+00, -2.88209884e-01, -5.23395910e-01,  5.50450329e-01,
#        -2.19496958e-01, -5.16862261e-03,  1.82819694e-01,  1.88869468e+00,
#        -9.50388556e-01, -1.53565560e-01,  1.39173970e+00,  4.34571134e-01,
#        -1.16193035e+00,  9.27400690e-01,  1.81064853e+00,  1.01948330e+00,
#         1.26471379e+00, -8.20407134e-03,  1.19318704e+00,  1.08394425e+00,
#         1.61991396e-01, -1.07243217e+00,  5.07876208e-01,  1.41834979e+00,
#         2.04983377e-01, -9.99358777e-01, -9.10371432e-01, -9.08351708e-01,
# ...

# %%
# 创建子图
fig, axs = plt.subplots(2,1)

# 填充数据、绘制图表
axs[0].hist(data, bins=50, color='red')
axs[1].plot(data, color='green')

# 参数设置
axs[0].set_title('normalized distribution')
axs[1].set_title('random sample')
axs[0].set_xlabel('value')
axs[0].set_ylabel('freq')
axs[1].set_xlabel('index')
axs[1].set_ylabel('value')

# tiao'zh

# 显示
plt.show()
